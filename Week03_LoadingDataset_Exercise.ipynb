# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylan2211/Colab_CVNL/blob/main/Week03_LoadingDataset_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch.utils.data import Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/CVNL"
# Out:
# 'a1a testing.txt'
#  a1a.txt
# 'Copy of Week01_IntroToPyTorch.ipynb'
#  idlmam.py
#  wdbc.data
#  wdbc.names
#  Week01_IntroToPyTorch.ipynb
#  Week02_Exercises.ipynb
#  Week02_PyTorchII.ipynb
#  Week03_LoadingDataset_Exercise.ipynb
# 'Week03_LoadingDataset.ipynb '
# 'Week03_NeuralNetworksII_Exercise.ipynb .ipynb'
# 'Week03_NeuralNetworksII.ipynb '

# %%
from sklearn.datasets import load_svmlight_file

# %%
class SimpleDataset(Dataset):

  def __init__(self, X, y):
    super(SimpleDataset, self).__init__()
    # self.X = X.to_numpy()
    self.X = X.toarray()
    self.y = y

  def __getitem__(self, index):
    inputs = torch.tensor(self.X[index,:], dtype=torch.float32)
    # targets = torch.tensor(int(self.y.iloc[index]), dtype=torch.int64)
    targets = torch.tensor(int(self.y[index]), dtype=torch.int64)
    return inputs, targets

  def __len__(self):
    return self.X.shape[0]

# %%
# I used SimpleDataset from the practice
def libsvm2Dataset(file_path):
  X, y = load_svmlight_file(file_path)
  return SimpleDataset(X, y)

# %%
train_path = '/content/drive/My Drive/Colab Notebooks/CVNL/a1a testing.txt'
test_path = '/content/drive/My Drive/Colab Notebooks/CVNL/a1a testing.txt'

# %%
train_dataset = libsvm2Dataset(train_path)
test_dataset = libsvm2Dataset(test_path)

# %%
# Code testing
from torch.utils.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size = 64, shuffle=True)
for inputs, targets in train_loader:
  print(inputs.shape, targets.shape)
  break
# Out:
# torch.Size([64, 123]) torch.Size([64])
